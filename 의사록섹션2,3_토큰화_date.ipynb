# %%
import pandas as pd
df = pd.read_csv('./minutes_section_sum.csv', encoding=u'utf-8')

# %%
del df['Unnamed: 0']

# %%
df
# Out:
#                                               section1  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7    일부 위원은 경제성장률 전망치가 전년동기대비로 보면 내년 하반기에 둔화되는 것으로 ...
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# ...

# %%
df['date'] = ''

# %%
dfdf = pd.read_csv('./moneminutes234.csv', encoding=u'utf-8')

# %%
dfdf
# Out:
#      Unnamed: 0      date                                             script
# 0             0  20050512  - 1 -金融通貨委員會 議事錄2005년도 제10차 회의1. 일 시 2005년 5월 ...
# 1             0  20050609  130.1.17.56-minute12.hwp- 1 -金融通貨委員會 議事錄2005년도...
# 2             0  20050707  130.1.17.56-minute14.hwp- 1 -金融通貨委員會 議事錄2005년도...
# 3             0  20050811  130.1.17.56-minute17.hwp- 1 -金融通貨委員會 議事錄2005년도...
# 4             0  20050908  130.1.17.56-minute19.hwp- 1 -金融通貨委員會 議事錄2005년도...
# 5             0  20051011  130.1.17.56-minute21.hwp- 1 -금융통화위원회 의사록2005년도...
# 6             0  20051110  130.1.17.56-minute24.hwp- 1 -금융통화위원회 의사록2005년도...
# 7             0  20051208  130.1.17.56-minute26.hwp- 1 -금융통화위원회 의사록2005년도...
# 8             0  20060112  <C1A632C2F720B1DDC5EBC0A720C0C7BBE7B7CF2E68777...
# 9             0  20060209  minute4.hwp금융통화위원회 의사록2006년도 제4차 회의1. 일    자  ...
# 10            0  20060309  minute6.hwp금융통화위원회 의사록2006년도 제6차 회의1. 일    자  ...
# ...

# %%
date_list = []
for i in range(len(dfdf)) :
    ry = dfdf['date'][i]
    date_list.append(ry)

# %%
date_list
# Out:
# [20050512,
#  20050609,
#  20050707,
#  20050811,
#  20050908,
#  20051011,
#  20051110,
#  20051208,
#  20060112,
#  20060209,
#  20060309,
#  20060407,
#  20060511,
#  20060608,
#  20060707,
#  20060810,
#  20060907,
#  20061012,
#  20061109,
#  20061207,
#  20070111,
#  20070208,
#  20070308,
#  20070412,
#  20070510,
#  20070608,
#  20070712,
#  20070809,
#  20070907,
#  20071011,
#  20071108,
#  20071207,
#  20080110,
#  20080213,
#  20080307,
#  20080410,
#  20080508,
#  20080612,
#  20080710,
#  20080807,
#  20080911,
#  20081009,
#  20081027,
#  20081107,
#  20081211,
#  20090109,
#  20090212,
#  20090312,
#  20090409,
#  20090512,
#  20090611,
#  20090709,
#  20090811,
#  20090910,
#  20091009,
#  20091112,
#  20091210,
#  20100108,
#  20100211,
#  20100311,
#  20100409,
#  20100512,
#  20100610,
#  20100709,
#  20100812,
#  20100909,
#  20101014,
#  20101116,
#  20101209,
#  20110113,
#  20110211,
#  20110310,
#  20110412,
#  20110513,
#  20110610,
#  20110714,
# ...

# %%
df['date'] = dfdf['date']

# %%
df.columns.tolist()
# Out:
# ['section1',
#  'section2',
#  'section3',
#  'section4',
#  'section5',
#  'section6',
#  'count1',
#  'count2',
#  'count3',
#  'count4',
#  'count5',
#  'count6',
#  'tokens2',
#  'tokens3',
#  'ngrams2',
#  'ngrams3',
#  'date']

# %%
cols = ['date', 'section1',
 'section2',
 'section3',
 'section4',
 'section5',
 'section6',
 'count1',
 'count2',
 'count3',
 'count4',
 'count5',
 'count6',
 'tokens2',
 'tokens3',
 'ngrams2',
 'ngrams3']

# %%
df = df[cols]
df
# Out:
#          date                                           section1  \
# 0    20050512                                                NaN
# 1    20050609                                                NaN
# 2    20050707                                                NaN
# 3    20050811                                                NaN
# 4    20050908                                                NaN
# 5    20051011                                                NaN
# 6    20051110                                                NaN
# 7    20051208  일부 위원은 경제성장률 전망치가 전년동기대비로 보면 내년 하반기에 둔화되는 것으로 ...
# 8    20060112                                                NaN
# 9    20060209                                                NaN
# 10   20060309                                                NaN
# 11   20060407                                                NaN
# 12   20060511                                                NaN
# ...

# %%
df['date'][29]
# Out:
# 20071011

# %%
df['date'][148] = '2017.11.30'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.tail()
# Out:
#            date                                           section1  \
# 144  2017.05.25  일부 위원은 금년 1/4분기 수출이 높은 증가율을 기록하였는데 단가 상승뿐만아니라 ...
# 145  2017.07.13  일부 위원은 이번 성장전망과 관련하여 금년 전망치 달성은 무난해 보이지만,내년에는 ...
# 146  2017.08.31  일부 위원은 관련부서에서는 세계경기의 회복세 강화, 추경 집행 등 상방 리스크 요인...
# 147  2017.10.19  일부 위원은 이번 경제전망을 보면 그동안 경기회복에도 불구하고 낮아졌던근원물가상승률...
# 148  2017.11.30  일부 위원은 9∼10월 실물경제 지표를 묶어서 보면 서비스업 생산이 늘어나는 가운데...
#
#                                               section2 section3 section4  \
# 144  일부 위원은 최근 국제금융시장이 안정된 모습을 지속하는 가운데 국내금융시장도 외국인...      NaN      NaN
# 145  일부 위원은 주요국에서는 성장과 고용이 회복국면의 정점을 향해 가고 있음에도 불구하...      NaN      NaN
# 146  일부 위원은 미국의 금리 정상화 행보에도 불구하고 미 달러화가 약세기조를지속하면서 ...      NaN      NaN
# 147  일부 위원은 최근 미국에서는 임금상승세가 확대되고 세제개혁에 대한 기대감이 커지면서...      NaN      NaN
# 148  일부 위원은 최근 미국의 금융·경제상황을 보면 금년 12월 미 연준이 금리를인상할 ...      NaN      NaN
#
#                                               section5  section6  count1  \
# ...

# %%
import pandas as pd
df.to_csv('./minutes_section_sum_date2.csv', encoding=u'utf-8',index = False)

# %%
pd.read_csv('./minutes_section_sum_date2.csv', encoding=u'utf-8')
# Out:
#            date                                           section1  \
# 0    2005.05.12                                                NaN
# 1    2005.06.09                                                NaN
# 2    2005.07.07                                                NaN
# 3    2005.08.11                                                NaN
# 4    2005.09.08                                                NaN
# 5    2005.10.11                                                NaN
# 6    2005.11.10                                                NaN
# 7    2005.12.08  일부 위원은 경제성장률 전망치가 전년동기대비로 보면 내년 하반기에 둔화되는 것으로 ...
# 8    2006.01.12                                                NaN
# 9    2006.02.09                                                NaN
# 10   2006.03.09                                                NaN
# 11   2006.04.07                                                NaN
# 12   2006.05.11                                                NaN
# ...

# %%
pd.read_csv('./bondreport4_1.csv', encoding=u'utf-8')
# Out:
#             date        com  \
# 0     2008.04.01    daewoo6
# 1     2008.04.07    daewoo4
# 2     2008.04.07    daewoo5
# 3     2008.04.14    daewoo3
# 4     2008.04.21    daewoo2
# 5     2008.04.28    daewoo1
# 6     2008.05.04    daewoo0
# 7     2008.05.13   daewoo29
# 8     2008.05.19   daewoo28
# 9     2008.05.20   daewoo27
# 10    2008.05.21   daewoo26
# 11    2008.05.22   daewoo25
# 12    2008.05.23   daewoo24
# 13    2008.05.26   daewoo22
# 14    2008.05.26   daewoo23
# 15    2008.05.27   daewoo21
# 16    2008.05.28   daewoo20
# 17    2008.05.29   daewoo19
# 18    2008.05.30   daewoo18
# 19    2008.06.02   daewoo17
# 20    2008.06.03   daewoo16
# 21    2008.06.04   daewoo15
# 22    2008.06.05   daewoo14
# 23    2008.06.09   daewoo13
# 24    2008.06.10   daewoo12
# 25    2008.06.11   daewoo11
# 26    2008.06.12   daewoo10
# 27    2008.06.13    daewoo8
# 28    2008.06.13    daewoo9
# 29    2008.06.16    daewoo6
# ...          ...        ...
# 3065  2017.11.22    kyobo29
# ...

# %%
pd.read_csv('./bondreport_merge_label.csv', encoding=u'utf-8')
# Out:
#             date                                              token  \
# 0     2008.04.01  가/VV.권투/NNG.자채/NNG.시장/NNG.전망/NNG.금융시장/NNG.차/NN...
# 1     2008.04.07  돌아온/VV.박스권/NNG.하단/NNG.상단/NNG.테스트/NNG.가능성/NNG.무...
# 2     2008.04.07  돌아온/VV.박스권/NNG.하단/NNG.상단/NNG.테스트/NNG.가능성/NNG.무...
# 3     2008.04.14  믹스/NNG.합의/NNG.반영/NNG.예상/NNG.경제/NNG.성장률/NNG.하향/...
# 4     2008.04.21  경기/NNG.전망/NNG.비교적/VAX.분명/MAG.인플레이션/NNG.명분/NNG....
# 5     2008.04.28  fed/NNG.원자재/NNG.가격/NNG.상승/NNG.둔화/NNG.여부/NNG.관심...
# 6     2008.05.04  가/VV.권투/NNG.자채/NNG.시장/NNG.전망/NNG.금융시장/NNG.차/NN...
# 7     2008.05.13  레인지/NNG.상단부/NNG.기회/NNG.다시/MAG.만들/VV.입장/NNG.우려/...
# 8     2008.05.19  채권/NNG.시황/NNG.만기/NNG.금리/NNG.상승/NNG.하/VV.만기/NNG...
# 9     2008.05.20  채권/NNG.시황/NNG.만기/NNG.금리/NNG.상승/NNG.하/VV.만기/NNG...
# 10    2008.05.21  채권/NNG.시황/NNG.만기/NNG.금리/NNG.하락/NNG.하/VV.만기/NNG...
# 11    2008.05.23  채권/NNG.시황/NNG.만기/NNG.금리/NNG.하락/NNG.하/VV.만기/NNG...
# 12    2008.05.26  채권/NNG.시황/NNG.만기/NNG.금리/NNG.상승/NNG.하/VV.만기/NNG...
# ...
